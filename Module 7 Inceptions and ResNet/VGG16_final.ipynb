# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.callbacks import LearningRateScheduler
from keras.optimizers import SGD,Adam
from tensorflow.keras import utils

from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np
import keras.backend as K

# %%
from keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
print("x_train shape" + str(x_train.shape))
print("y_train shape" + str(y_train.shape))
# Out:
# x_train shape(50000, 32, 32, 3)
# y_train shape(50000, 1)

# %%
fig=plt.figure(figsize=(16, 8))
columns = 10
rows = 5
for i in range(1, columns*rows +1):
    img = x_train[i]
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
X_train = x_train.astype('float32')
X_test = x_test.astype('float32')
X_train /= 255
X_test /= 255

# %%
Y_train = utils.to_categorical(y_train, 10)
Y_test = utils.to_categorical(y_test, 10)

# %%
model = Sequential()

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(32,32,3)))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))


model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))


model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
sgd = SGD(lr=1e-3, momentum=0.9, nesterov=True)

adam = Adam(lr=1e-3)

# 8. Compile model
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
min_epochs = 40  # After this number, user will be asked whether to run another epoch or not
factor = 10 # Factor by which learning rate should be decreased
e_red = 0

# Learning Rate Scheduler
def scheduler(epoch):
  n = K.eval(model.optimizer.lr)
  if i == 'R' or i == 'r':
    n /= factor
  return n

change_lr = LearningRateScheduler(scheduler)
callbacks_list = [change_lr]


count = 1
flag = 1
i = 'y'
val = []
train = []

while flag==1:

  print("\n\nINFO: Training epoch number: " + str(count) + " with learning rate: " + str(K.eval(model.optimizer.lr)) + "\n")

  history = model.fit(X_train, Y_train, batch_size=32, epochs=1, verbose=1,validation_split=0.1,callbacks=callbacks_list)


  # Appending validation accuracy to list to check whether lr needs to be reduced
  val.append(history.history['val_accuracy'])
  train.append(history.history['accuracy'])

  # To decrease learning rate
  if len(val) > 3:
    if val[len(val)-1][0] - val[len(val)-4][0] < 0.01 and count - e_red > 2:
      print("INFO: Reducing learning rate by factor of 10 after the next epoch")
      # Setting the parameter for scheduler
      i = 'r'
      e_red = count
    else:
      i = 'n'

  # Checking if another epoch needs to be run
  if count > min_epochs:
    print("Type y for running another epoch")
    print("Type n to stop the training")
    inp = input()
    if inp == 'y' or inp == 'Y':
      flag = 1
    elif inp == 'n' or inp == 'N':
      flag = 0

  #Increasing the epoch number
  count += 1
# Out:
# INFO: Training epoch number: 1 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 1.6965 - accuracy: 0.3275 - val_loss: 1.7707 - val_accuracy: 0.3362 - lr: 0.0010
#
#
# INFO: Training epoch number: 2 with learning rate: 0.001
#
# 1407/1407 [==============================] - 49s 35ms/step - loss: 1.5572 - accuracy: 0.3924 - val_loss: 1.7987 - val_accuracy: 0.3644 - lr: 0.0010
#
#
# INFO: Training epoch number: 3 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 1.3837 - accuracy: 0.4907 - val_loss: 1.9443 - val_accuracy: 0.3336 - lr: 0.0010
#
#
# INFO: Training epoch number: 4 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 1.1940 - accuracy: 0.5870 - val_loss: 1.0620 - val_accuracy: 0.6196 - lr: 0.0010
#
#
# INFO: Training epoch number: 5 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 1.0326 - accuracy: 0.6562 - val_loss: 0.9866 - val_accuracy: 0.6740 - lr: 0.0010
#
#
# INFO: Training epoch number: 6 with learning rate: 0.001
#
# 1407/1407 [==============================] - 49s 35ms/step - loss: 0.9233 - accuracy: 0.6940 - val_loss: 0.7964 - val_accuracy: 0.7422 - lr: 0.0010
#
#
# INFO: Training epoch number: 7 with learning rate: 0.001
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.9045 - accuracy: 0.7024 - val_loss: 0.9025 - val_accuracy: 0.6950 - lr: 0.0010
#
#
# INFO: Training epoch number: 8 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 0.7798 - accuracy: 0.7493 - val_loss: 1.5245 - val_accuracy: 0.7698 - lr: 0.0010
#
#
# INFO: Training epoch number: 9 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.7093 - accuracy: 0.7744 - val_loss: 0.7055 - val_accuracy: 0.7742 - lr: 0.0010
#
#
# INFO: Training epoch number: 10 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.6466 - accuracy: 0.7943 - val_loss: 0.5895 - val_accuracy: 0.8058 - lr: 0.0010
#
#
# INFO: Training epoch number: 11 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 0.5917 - accuracy: 0.8106 - val_loss: 0.6873 - val_accuracy: 0.7912 - lr: 0.0010
#
#
# INFO: Training epoch number: 12 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 0.5504 - accuracy: 0.8266 - val_loss: 0.6526 - val_accuracy: 0.7932 - lr: 0.0010
#
#
# INFO: Training epoch number: 13 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.5004 - accuracy: 0.8409 - val_loss: 0.6409 - val_accuracy: 0.8038 - lr: 0.0010
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 14 with learning rate: 0.001
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 0.3550 - accuracy: 0.8851 - val_loss: 0.4751 - val_accuracy: 0.8548 - lr: 1.0000e-04
#
#
# INFO: Training epoch number: 15 with learning rate: 0.000100000005
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.3156 - accuracy: 0.8971 - val_loss: 0.4773 - val_accuracy: 0.8558 - lr: 1.0000e-04
#
#
# INFO: Training epoch number: 16 with learning rate: 0.000100000005
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 0.2959 - accuracy: 0.9034 - val_loss: 0.4835 - val_accuracy: 0.8588 - lr: 1.0000e-04
#
#
# INFO: Training epoch number: 17 with learning rate: 0.000100000005
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2771 - accuracy: 0.9108 - val_loss: 0.4842 - val_accuracy: 0.8590 - lr: 1.0000e-04
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 18 with learning rate: 0.000100000005
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2552 - accuracy: 0.9160 - val_loss: 0.4849 - val_accuracy: 0.8620 - lr: 1.0000e-05
#
#
# INFO: Training epoch number: 19 with learning rate: 1.0000001e-05
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2544 - accuracy: 0.9169 - val_loss: 0.4870 - val_accuracy: 0.8614 - lr: 1.0000e-05
#
#
# INFO: Training epoch number: 20 with learning rate: 1.0000001e-05
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2547 - accuracy: 0.9174 - val_loss: 0.4927 - val_accuracy: 0.8604 - lr: 1.0000e-05
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 21 with learning rate: 1.0000001e-05
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2489 - accuracy: 0.9181 - val_loss: 0.4911 - val_accuracy: 0.8596 - lr: 1.0000e-06
#
#
# INFO: Training epoch number: 22 with learning rate: 1.0000001e-06
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2504 - accuracy: 0.9187 - val_loss: 0.4916 - val_accuracy: 0.8600 - lr: 1.0000e-06
#
#
# INFO: Training epoch number: 23 with learning rate: 1.0000001e-06
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2512 - accuracy: 0.9179 - val_loss: 0.4927 - val_accuracy: 0.8598 - lr: 1.0000e-06
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 24 with learning rate: 1.0000001e-06
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2489 - accuracy: 0.9191 - val_loss: 0.4942 - val_accuracy: 0.8590 - lr: 1.0000e-07
#
#
# INFO: Training epoch number: 25 with learning rate: 1.0000001e-07
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2499 - accuracy: 0.9201 - val_loss: 0.4905 - val_accuracy: 0.8594 - lr: 1.0000e-07
#
#
# INFO: Training epoch number: 26 with learning rate: 1.0000001e-07
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 0.2505 - accuracy: 0.9177 - val_loss: 0.4905 - val_accuracy: 0.8598 - lr: 1.0000e-07
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 27 with learning rate: 1.0000001e-07
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.2489 - accuracy: 0.9178 - val_loss: 0.4899 - val_accuracy: 0.8604 - lr: 1.0000e-08
#
#
# INFO: Training epoch number: 28 with learning rate: 1.0000001e-08
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2497 - accuracy: 0.9187 - val_loss: 0.4930 - val_accuracy: 0.8596 - lr: 1.0000e-08
#
#
# INFO: Training epoch number: 29 with learning rate: 1.0000001e-08
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2475 - accuracy: 0.9194 - val_loss: 0.4928 - val_accuracy: 0.8594 - lr: 1.0000e-08
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 30 with learning rate: 1.0000001e-08
#
# 1407/1407 [==============================] - 47s 33ms/step - loss: 0.2494 - accuracy: 0.9186 - val_loss: 0.4930 - val_accuracy: 0.8600 - lr: 1.0000e-09
#
#
# INFO: Training epoch number: 31 with learning rate: 1.0000001e-09
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.2496 - accuracy: 0.9198 - val_loss: 0.4915 - val_accuracy: 0.8600 - lr: 1.0000e-09
#
#
# INFO: Training epoch number: 32 with learning rate: 1.0000001e-09
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.2515 - accuracy: 0.9171 - val_loss: 0.4922 - val_accuracy: 0.8604 - lr: 1.0000e-09
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 33 with learning rate: 1.0000001e-09
#
# 1407/1407 [==============================] - 49s 35ms/step - loss: 0.2457 - accuracy: 0.9199 - val_loss: 0.4908 - val_accuracy: 0.8598 - lr: 1.0000e-10
#
#
# INFO: Training epoch number: 34 with learning rate: 1.0000001e-10
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.2518 - accuracy: 0.9174 - val_loss: 0.4927 - val_accuracy: 0.8600 - lr: 1.0000e-10
#
#
# INFO: Training epoch number: 35 with learning rate: 1.0000001e-10
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.2458 - accuracy: 0.9183 - val_loss: 0.4924 - val_accuracy: 0.8588 - lr: 1.0000e-10
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 36 with learning rate: 1.0000001e-10
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2492 - accuracy: 0.9185 - val_loss: 0.4909 - val_accuracy: 0.8600 - lr: 1.0000e-11
#
#
# INFO: Training epoch number: 37 with learning rate: 1.0000001e-11
#
# 1407/1407 [==============================] - 47s 34ms/step - loss: 0.2479 - accuracy: 0.9191 - val_loss: 0.4908 - val_accuracy: 0.8602 - lr: 1.0000e-11
#
#
# INFO: Training epoch number: 38 with learning rate: 1.0000001e-11
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2486 - accuracy: 0.9171 - val_loss: 0.4917 - val_accuracy: 0.8604 - lr: 1.0000e-11
# INFO: Reducing learning rate by factor of 10 after the next epoch
#
#
# INFO: Training epoch number: 39 with learning rate: 1.0000001e-11
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2467 - accuracy: 0.9190 - val_loss: 0.4929 - val_accuracy: 0.8600 - lr: 1.0000e-12
#
#
# INFO: Training epoch number: 40 with learning rate: 1.0000001e-12
#
# 1407/1407 [==============================] - 48s 34ms/step - loss: 0.2490 - accuracy: 0.9171 - val_loss: 0.4895 - val_accuracy: 0.8598 - lr: 1.0000e-12
#
#
# INFO: Training epoch number: 41 with learning rate: 1.0000001e-12
#
# 1407/1407 [==============================] - 49s 35ms/step - loss: 0.2463 - accuracy: 0.9190 - val_loss: 0.4910 - val_accuracy: 0.8592 - lr: 1.0000e-12
# INFO: Reducing learning rate by factor of 10 after the next epoch
# Type y for running another epoch
# Type n to stop the training
# n

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.set_title('Validation Accuracy vs Training Accuracy', color='C0')
ax.plot(range(1,len(train)+1),train[:len(train)],  label='Training Accuracy',color='red')
ax.plot(range(1,len(train)+1),val, label='Validation Accuracy', color='green')
ax.legend()

# %%
 # 10. Evaluate model on test data
score = model.evaluate(X_test, Y_test, verbose=0)
print("Loss: " + str(score[0]))
print("Accuracy: " + str(score[1]*100) + "%")
# Out:
# Loss: 0.50541752576828
# Accuracy: 85.55999994277954%
